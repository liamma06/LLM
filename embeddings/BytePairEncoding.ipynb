# %% [markdown]
# # Byte Pair encoding
# More sophisicated

# %%
pip install tiktoken
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\liamj\OneDrive\Documents\LLM\.venv\Scripts\python.exe: No module named pip

# %%
from importlib.metadata import version
import tiktoken
print(version("tiktoken"))
# Out:
# 0.12.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")
text = (
    "Hello, do you like tea? <|endoftext|> In the sunlit"
    "of someunknownPlace."
)
integers = tokenizer.encode(text,allowed_special={"<|endoftext|>"})
print (integers)

strings = tokenizer.decode(integers)
print (strings)

#better alternative for same result
# Out:
# [15496, 11, 466, 345, 588, 8887, 30, 220, 50256, 554, 262, 4252, 18250, 1659, 617, 34680, 27271, 13]
# Hello, do you like tea? <|endoftext|> In the sunlitof someunknownPlace.

# %% [markdown]
# BPE is able to encode unkown words by breaking odwn words into smaller sub units or characters.
# ![image.png](attachment:image.png)
